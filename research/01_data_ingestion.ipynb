# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Abhishek\\Downloads\\END-TO-END-MACHINE-LEARNING-PROJECT-WITH-ML-FLOW\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Abhishek\\Downloads\\END-TO-END-MACHINE-LEARNING-PROJECT-WITH-ML-FLOW'
